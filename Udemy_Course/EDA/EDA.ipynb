# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Common EDA technoques

# %% [markdown]
# #### Exploring data
# Example:
# Filetring
# Sorting
# Grouping

# %% [markdown]
# #### Visualizing data
# Example: Histograms
# ScatterPlot
# Pair Plots

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_pickle('../Gathering and Cleaning  Data/groceries_with_new_columna.pkl')
df
# Out:
#    Product_ID  Product_Id_No Category     SubCategory  Price_Dollars  \
# 0     P100010         100010  Produce           Fruit           1.50
# 1     P100011         100011  Produce           Fruit           0.40
# 2     P100012         100012  Produce           Fruit           4.00
# 3     P100013         100013  Produce           Fruit           0.99
# 4     P100014         100014  Produce           Fruit           3.99
# 5     P100015         100015  Produce           Fruit           5.99
# 6     P100016         100016  Produce       Vegetable           1.78
# 7     P100017         100017  Produce       Vegetable           2.00
# 8     P100018         100018  Produce       Vegetable           1.99
# 9     P100019         100019  Produce       Vegetable           0.99
# 10    P100020         100020  Produce            Meat           8.99
# 11    P100021         100021  Produce            Meat          10.49
# 12    P100022         100022  Produce            Meat           7.99
# ...

# %%
#DEMO: filtering 
df.loc[df['Inventory Flag']=='Low Inventory', Price_Dollars]
# Out:
#    Product_ID  Product_Id_No Category SubCategory  Price_Dollars  Inventory  \
# 15    P100025         100025  Produce       Dairy           4.49         32
# 17    P100027         100027   Pantry      Snacks           1.50         27
# 20    P100030         100030   Pantry      Snacks           2.99          5
#
#     Pecentage Inventory Inventory Flag        Last_Updated LastUpdatedTiime  \
# 15                 0.66  Low Inventory 2023-06-13 08:37:00         08:37:00
# 17                 0.56  Low Inventory 2023-06-10 12:02:00         12:02:00
# 20                 0.10  Low Inventory 2023-06-10 12:38:00         12:38:00
#
#    Next_Scheduled_Shipment Shipment_Date_Dow
# 15              2023-06-17          Saturday
# 17              2023-06-24          Saturday
# 20              2023-06-24          Saturday
